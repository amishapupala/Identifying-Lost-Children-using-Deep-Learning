# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

imgname="Irica.jpg"
originalImg=mpimg.imread('../Aging/OriginalCrop/'+imgname)
ageProgressedImg=mpimg.imread('../Aging/Age Progressed/'+imgname)


'''
plt.figure(figsize=(15, 15))
plt.subplot(121)
plt.title("Original Image") 
plt.imshow(originalImg)


plt.figure(figsize=(15, 15))
plt.subplot(122)
plt.title("Age Progressed Image") 
plt.imshow(ageProgressedImg)



plt.figure(figsize=(15, 15))
plt.subplot(122)
plt.title("Age Progressed Image") 
plt.imshow(ageProgressedImg)
f, axarr = plt.subplots(2,2)
axarr[0,0].imshow(originalImg)
axarr[0,1].imshow(ageProgressedImg)'''


fig = plt.figure(figsize=(15, 15))
ax1 = fig.add_subplot(2,2,1)
plt.title("Original Image") 
ax1.imshow(originalImg)
ax2 = fig.add_subplot(2,2,2)
plt.title("Age Progressed Image") 
ax2.imshow(ageProgressedImg)

# %%
def AgeProgress(imgname):
    originalImgCrop=mpimg.imread('../Aging/OriginalCrop/'+imgname)
    ageProgressedImg=mpimg.imread('../Aging/Age Progressed/'+imgname)
